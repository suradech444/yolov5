# %%
# !git clone https://github.com/suradech444/yolov5  # clone
# %cd /content/yolov5
# %pip install -qr requirements.txt  # install

import torch
from IPython.display import Image, clear_output
clear_output()

# %%
# %pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.8 MB 4.3 MB/s
#      |████████████████████████████████| 144 kB 90.6 MB/s
#      |████████████████████████████████| 181 kB 85.8 MB/s
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train.py  --epochs 3000 --data freckles.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  6.74it/s]
#                  all         38       6488      0.789      0.514      0.605      0.242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1665/9999     4.63G    0.1298    0.2771         0      1032       640: 100% 3/3 [00:00<00:00,  5.88it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  6.65it/s]
#                  all         38       6488      0.779      0.521      0.606       0.24
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#  1666/9999     4.63G    0.1318    0.2385         0      1398       640: 100% 3/3 [00:00<00:00,  5.91it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:00<00:00,  6.80it/s]
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.25 --source test/ --save-txt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 c7fc2a4 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test/002.jpg: 384x640 131 freckless, Done. (0.017s)
# Speed: 0.5ms pre-process, 17.0ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
# 1 labels saved to runs/detect/exp2/labels

# %%
# !python detect.py --weights /content/yolov5/runs/best.onnx --conf 0.25 --source test/
# Out:
# detect: weights=['/content/yolov5/runs/best.onnx'], source=test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 d46e2df torch 1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Loading /content/yolov5/runs/best.onnx for ONNX Runtime inference...
# requirements: onnx not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: onnxruntime-gpu not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# ...

# %%
# !python export.py --weights /content/yolov5/runs/train/exp/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 c7fc2a4 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp/weights/best.pt with output shape (1, 25200, 6) (13.7 MB)
#
# TorchScript: starting export with torch 1.11.0+cu113...
# TorchScript: export success, saved as /content/yolov5/runs/train/exp/weights/best.torchscript (27.2 MB)
#
# ONNX: starting export with onnx 1.11.0...
# ONNX: export success, saved as /content/yolov5/runs/train/exp/weights/best.onnx (27.2 MB)
#
# Export complete (4.77s)
# ...

# %%
# !python export.py --weights /content/yolov5/runs/train/exp/weights/best.pt --include engine onnx --data /content/yolov5/data/freckles.yaml --device 0
# Out:
# export: data=/content/yolov5/data/freckles.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=0, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['engine', 'onnx']
# YOLOv5 🚀 c7fc2a4 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp/weights/best.pt with output shape (1, 25200, 6) (13.7 MB)
#
# ONNX: starting export with onnx 1.11.0...
# WARNING: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function.
# ...

# %%
import cv2

model = torch.hub.load('suradech444/yolov5', 'custom', path='best.pt')

# Image
img = cv2.imread('test/002.jpg')

# Inference
results = model(img) # pass the image through our model

results.pandas().xyxy[0]
results.print()
# Out:
# Downloading: "https://github.com/suradech444/yolov5/archive/main.zip" to /root/.cache/torch/hub/main.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/suradech444_yolov5_main/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-4-26 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 563x1000 9 freckless
# Speed: 12.0ms pre-process, 45.5ms inference, 34.0ms NMS per image at shape (1, 3, 384, 640)
